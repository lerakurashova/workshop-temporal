# %%
import os
from urllib.parse import quote
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.proxies import WebshareProxyConfig

# %%
PROXY_USER = os.environ["WEBSHARE_PROXY_USER"]
PROXY_PASS = quote(os.environ["WEBSHARE_PROXY_PASS"])

# %%
ytt_api = YouTubeTranscriptApi(
    proxy_config=WebshareProxyConfig(
        proxy_username=PROXY_USER,
        proxy_password=PROXY_PASS,
        filter_ip_locations=["de", "us"],
    )
)

# %%
video_id = '4bl2TSHD_Fc'
transcript = ytt_api.fetch(video_id)

# %%
transcript
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Hi everyone, welcome to our event. This', start=0.48, duration=4.16), FetchedTranscriptSnippet(text='event is brought to you by data talks', start=3.12, duration=3.44), FetchedTranscriptSnippet(text='club which is a community of people who', start=4.64, duration=3.919), FetchedTranscriptSnippet(text='love data. We have weekly events. Today', start=6.56, duration=3.44), FetchedTranscriptSnippet(text='is one of such events. If you want to', start=8.559, duration=3.2), FetchedTranscriptSnippet(text='find out more about the events we have,', start=10.0, duration=3.28), FetchedTranscriptSnippet(text='there is a link in the description. Go', start=11.759, duration=3.521), FetchedTranscriptSnippet(text="there, click on that link and you'll see", start=13.28, duration=4.079), FetchedTranscriptSnippet(text='you will see all the event we have in', start=15.28, duration=4.079), FetchedTranscriptSnippet(text='our pipeline. Then do not forget to', start=17.359, duration=3.601), FetchedTranscriptSnippet(text='subscribe to our YouTube channel. Very', start=19.359, duration=3.361), FetchedTranscriptSnippet(text="important. This way you'll get notified", start=20.96, duration=4.64), FetchedTranscriptSnippet(text='about all the futures we have. And last', start=22.72, duration=4.639), FetchedTranscriptSnippet(text='but not least, we have an amazing Slack', start=25.6, duration=3.28), FetchedTranscriptSnippet(text='community where you can hang out with', start=27.359, duration=3.521), FetchedTranscriptSnippet(text='other data enthusiasts. There is a link', start=28.88, duration=4.0), FetchedTranscriptSnippet(text='in the description. Click on that link.', start=30.88, duration=4.96), FetchedTranscriptSnippet(text="Uh sign up and then you'll get invite uh", start=32.88, duration=5.28), FetchedTranscriptSnippet(text="you'll get invited to our Slack. During", start=35.84, duration=4.08), FetchedTranscriptSnippet(text="today's interview, you can ask any", start=38.16, duration=3.52), FetchedTranscriptSnippet(text='question you want. There is a pinned', start=39.92, duration=3.6), FetchedTranscriptSnippet(text='link in the live chat. Click on that', start=41.68, duration=4.24), FetchedTranscriptSnippet(text='link, ask your questions, and we will be', start=43.52, duration=3.76), FetchedTranscriptSnippet(text='covering your questions during the', start=45.92, duration=4.159), FetchedTranscriptSnippet(text="interview. And now I'm stopping sharing", start=47.28, duration=6.32), FetchedTranscriptSnippet(text="my screen. I'm opening the document with", start=50.079, duration=6.32), FetchedTranscriptSnippet(text='questions', start=53.6, duration=4.479), FetchedTranscriptSnippet(text='and', start=56.399, duration=5.281), FetchedTranscriptSnippet(text='yeah, we can start.', start=58.079, duration=5.361), FetchedTranscriptSnippet(text='>> Sounds great to me. [laughter]', start=61.68, duration=4.0), FetchedTranscriptSnippet(text='>> Took a sip of your tea. So, it seems', start=63.44, duration=4.64), FetchedTranscriptSnippet(text='ready. So, I already showed it to', start=65.68, duration=4.32), FetchedTranscriptSnippet(text="Sophia. I'll show it one more time. So,", start=68.08, duration=5.039), FetchedTranscriptSnippet(text='this is a souvenir I have uh from', start=70.0, duration=5.04), FetchedTranscriptSnippet(text='Websummit. This is a conference I', start=73.119, duration=3.921), FetchedTranscriptSnippet(text='attended recently.', start=75.04, duration=4.88), FetchedTranscriptSnippet(text='Was it two three weeks ago? Um', start=77.04, duration=5.92), FetchedTranscriptSnippet(text='>> it was almost I guess a month ago', start=79.92, duration=4.4), FetchedTranscriptSnippet(text='>> month ago. Time flies.', start=82.96, duration=1.76), FetchedTranscriptSnippet(text='>> Yeah.', start=84.32, duration=1.68), FetchedTranscriptSnippet(text='>> Uh [laughter]', start=84.72, duration=5.2), FetchedTranscriptSn ...
